# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
fig,ax=plt.subplots()
x=[8,9,7,5,45,11,6,5,7,3,8,2,8]
y=[1,6,8,4,6,2,4,8,3,4,8,9,10]
ax.scatter(x,y)

# %%
df=pd.read_csv("Data/Iris.csv - Iris.csv.csv",index_col=0)
df.head(5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig,ax=plt.subplots()
ax.scatter(df["SepalLengthCm"],df["SepalWidthCm"])
ax.set_title("iris Dataset")
ax.set_xlabel("Sepal Length")
ax.set_ylabel("Sepal width")
# Out:
# Text(0, 0.5, 'Sepal width')

# %%
import numpy as np
x=range(1,6)
y=np.random.randint(1,20,5)
plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x2558d685fa0>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
fig,ax=plt.subplots()
x=[8,9,7,5,45,11,6,5,7,3,8,2,8]
y=[1,6,8,4,6,2,4,8,3,4,8,9,10]

plt.plot(x,y)
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x2558d6da1f0>,
# ...
#  <a list of 13 Text yticklabel objects>)

# %%
df1=pd.DataFrame({
    "Name":["Chaitanya","Suraj","Saurav","Nishant","Shubham"],
    "Age":[20,21,20,21,20],
    "Gender":['M','M','M','M','M'],
    "Marks":[70,80,90,91,92]
    
})
ax=plt.gca()
df.plot(kind='line',x='Name',y='Marks',ax=ax)
df.plot(kind='line',x='Name',y='Age',ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\sample projects\sample_project1\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-412355e5c3bc> in <module>
#       7 })
# ...

# %%
col=df.columns.drop(['Species'])
x1=range(0,df.shape[0])
fig,ax=plt.subplots()
for column in col:
    ax.plot(x1,df[column],label=column)
ax.set_title('Iris Dataset')
ax.legend
# Out:
# <bound method Axes.legend of <matplotlib.axes._subplots.AxesSubplot object at 0x000002558D9D96A0>>

# %%
fig,ax=plt.subplots()
ax.hist(df["SepalLengthCm"])
ax.set_title("iris Dataset")
ax.set_xlabel("Sepal Length")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data=pd.read_csv("Data/winemag-data-130k-v2.csv",index_col=0)
data.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
fig,ax=plt.subplots()
data1=data['points'].value_counts()
points=data1.index
frequency=data1.values
ax.bar(points,frequency)
ax.set_title("WRS")
ax.set_xlabel("Points")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data.groupby("country").price.mean().sort_values(ascending=False)[:10].plot.bar()

# %%
obj=("Python","C","Java","Pearl")
y_pos=np.arange(len(obj))
per=[10,9,6,6]
plt.bar(y_pos,per,width=0.8,align='edge',alpha=0.7,color=['red','blue','grey','orange'])
plt.xticks(y_pos,obj)
plt.ylabel("Usage")
plt.xlabel("Language")
plt.title("PLU")
# Out:
# Text(0.5, 1.0, 'PLU')

# %%
plt.figure(figsize=(12,7))
countries=['USA',"bRAZIL","RUSSIA",'SPAIN','UK']
totalDeaths=[112596,37312,5971,27136,40597]
plt.bar(countries,totalDeaths,width=0.9,align='center',color='cyan',edgecolor='red')
i=1.0
j=2000
for i in range(len(countries)):
    plt.annotate(totalDeaths[i],(-0.1+i,totalDeaths[i]+ j))
    plt.legend(labels=['Total Deaths'])
    plt.title("BAr plot representing")
    plt.xlabel("Countries")
    plt.ylabel("Deaths")
    plt.savefig("1BarPlot.png")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\sample projects\sample_project1\env\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# D:\sample projects\sample_project1\env\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
data["points"].value_counts().sort_index().plot.barh()

# %%
plt.figure(figsize=[14,10])
plt.barh(["USA","UK","France","Brazil","Spain"],[5000,5120,8701,7111,1111],label="Danger",color="r")
plt.barh(["India","China","Russia","Israel","Australia"],[2600,5991,2701,7111,3111],label="Safe",color="green")
plt.legend()
plt.xlabel("Total Cases")
plt.ylabel("Country")
plt.title("Covid 19 status")
plt.savefig("barplot2.png")
plt.show()

# %%
df1=pd.DataFrame({
    "Namw":["Chaitanya","Suraj","Saurav"],
    "gender":["M","M","M"],
    "Age":[21,20,20],
    "State":["Maharashtra","Bihar","Bihar"],
    "num_children":[0,10,1],
    "num_pets":[5,1,0]
})
df1.groupby(["State","num_pets"]).size().unstack().plot(kind="bar",stacked=True)

# %%
D1={
    "Country":["USA","RUSSIA","CANADA"],
    "gdp":[45000,42000,35000],
    "Income":[4000,5000,6000],
    
}
D11=pd.DataFrame(D1)
D11.plot(x="Country",y=["gdp","Income"],kind="bar")

# %%
plt.figure(figsize=[15,10])
total_death=[15000,21000,3100,2000]
total_recovery=[77700,45000,60000,50000]
active_case=[70000,46000,4715,11100]
country=["USA","INDIA","UK","BRAZIL"]
X=np.arange(len(total_death))
plt.bar(X,total_death,color='r',width=0.25)
plt.bar(X+0.25,total_recovery,color='green',width=0.25)
plt.bar(X+0.5,active_case,color='orange',width=0.25)
plt.legend(["Total Deaths","Total Recoveries","Active Cases"])
plt.xticks([i+0.25 for i in range(5)],country)
plt.title("Covid-19")
plt.savefig("bar3.png")
plt.show()

# %%
Data2={'Tasks':[300,500,700],
     'Task Type':["Tasks Pending",'Tasks Ongoing','Tasks Completed']
     }
df2=pd.DataFrame(Data2)
df2.set_index("Task Type",inplace=True)
df2.plot.pie(y='Tasks',figsize=(10,10),autopct='%1.1f%%',startangle=90);

# %%
# %matplotlib inline 
labels=["Civil","Mechanical","Chemical"]
sizes=[15,30,45]
explode=(0.1,0.1,0.4)
fig,ax=plt.subplots()
ax.pie(sizes,
      explode=explode,
      labels=labels,
      autopct="%1.1f%%",
      shadow=True,
      startangle=90)
ax.axis("equal")
ax.set_title("Engineering")
# Out:
# Text(0.5, 1.0, 'Engineering')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,1")

plt.subplot(2,2,2)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,2")

plt.subplot(2,2,3)
plt.scatter(range(1,6),np.random.randint(1,20,5),s=100,color="r")
plt.title("2,2,3")

plt.subplot(2,2,4)
plt.plot(range(1,6),np.random.randint(1,20,5),marker="o",color="r",linestyle="--")
plt.title("2,2,4")
# Out:
# Text(0.5, 1.0, '2,2,4')

# %%
plt.bar(range(1,6),np.random.randint(1,20,5),width=0.5)
plt.scatter(range(1,6),np.random.randint(1,20,5),s=200,color="r")
plt.plot(range(1,6),np.random.randint(1,20,5),marker='o',color='g',linestyle='--');

# %%
cars_data=pd.read_csv("Data/Toyota.csv - Toyota.csv.csv",index_col=0,na_values=["??","????"])
cars_data.head()
cars_data.size
# Out:
# 14360

# %%
cars_data.dropna(axis=0,inplace=True)

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86.0       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86.0       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86.0       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86.0       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
sns.set(style='darkgrid')
sns.regplot(x=cars_data["Age"],y=cars_data["Price"])

# %%
sns.regplot(x=cars_data["Age"],y=cars_data["Price"],fit_reg=False)

# %%
sns.regplot(x=cars_data["Age"],y=cars_data["Price"],marker="*",fit_reg=False)

# %%
sns.lmplot(x='Age',y='Price',data=cars_data,fit_reg=False,hue='FuelType',legend=True,palette='Set3');
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars_data["Age"])
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cars_data["Age"],kde=False,bins=5)
# Out:
# D:\sample projects\sample_project1\env\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="FuelType",data=cars_data)

# %%
sns.countplot(x="FuelType",data=cars_data,hue="Automatic")

# %%
pd.crosstab(index=cars_data['Automatic'],columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58
